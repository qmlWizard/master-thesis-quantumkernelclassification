# %%
import matplotlib.pyplot as plt
import networkx as nx
from pymgrid import Microgrid

# Define microgrid components
components = {
    'generators': [
        {'name': 'Gen1', 'type': 'generator', 'capacity': 1000, 'cost': 0.1}
    ],
    'loads': [
        {'name': 'Load1', 'type': 'load', 'demand': 500}
    ],
    'storages': [
        {'name': 'Storage1', 'type': 'storage', 'capacity': 200, 'charge_rate': 50, 'discharge_rate': 50}
    ]
}

# Create microgrid instance
microgrid = Microgrid(components)

# Add components to the microgrid
for gen in components['generators']:
    microgrid.add_generator(gen['name'], gen['capacity'], gen['cost'])

for load in components['loads']:
    microgrid.add_load(load['name'], load['demand'])

for storage in components['storages']:
    microgrid.add_storage(storage['name'], storage['capacity'], storage['charge_rate'], storage['discharge_rate'])

# Define faults
def simulate_faults(microgrid, fault_type, component_name, start_time, duration):
    microgrid.add_fault(fault_type=fault_type, component_name=component_name, start_time=start_time, duration=duration)

# Simulate faults
simulate_faults(microgrid, fault_type='line_A_to_ground', component_name='Load1', start_time=5, duration=2)
simulate_faults(microgrid, fault_type='line_B_to_ground', component_name='Gen1', start_time=10, duration=3)

# Simulate microgrid operation
simulation_duration = 20  # in seconds
time_series_data = microgrid.simulate(simulation_duration)

# Convert the time series data to a DataFrame
import pandas as pd
df = pd.DataFrame(time_series_data)

# Save the data for further analysis
df.to_csv('microgrid_simulation_data.csv', index=False)

# Print the collected data
print(df.head())

# Visualize microgrid using networkx and matplotlib
G = nx.Graph()

# Add nodes for each component
for gen in components['generators']:
    G.add_node(gen['name'], type='Generator')
for load in components['loads']:
    G.add_node(load['name'], type='Load')
for storage in components['storages']:
    G.add_node(storage['name'], type='Storage')

# Assuming connections (edges) based on the hypothetical microgrid configuration
G.add_edge('Gen1', 'Load1')
G.add_edge('Gen1', 'Storage1')
G.add_edge('Storage1', 'Load1')

# Define node positions for visualization
pos = {
    'Gen1': (0, 1),
    'Load1': (1, 0),
    'Storage1': (1, 1)
}

# Draw the network graph
plt.figure(figsize=(8, 6))
nx.draw(G, pos, with_labels=True, node_size=3000, node_color='lightblue', font_size=10, font_weight='bold', edge_color='gray')
plt.title('Microgrid Configuration')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 19
#       6 components = {
#       7     'generators': [
#       8         {'name': 'Gen1', 'type': 'generator', 'capacity': 1000, 'cost': 0.1}
#    (...)
#      15     ]
#      16 }
#      18 # Create microgrid instance
# ---> 19 microgrid = Microgrid(components)
#      21 # Add components to the microgrid
#      22 for gen in components['generators']:
#
# File ~/Developer/MasterThesis/master-thesis-quantumkernelclassification/.venv/lib/python3.12/site-packages/pymgrid/microgrid/microgrid.py:111, in Microgrid.__init__(self, modules, add_unbalanced_module, loss_load_cost, overgeneration_cost, reward_shaping_func, trajectory_func)
#     103 def __init__(self,
#     104              modules,
#     105              add_unbalanced_module=True,
#    (...)
#     108              reward_shaping_func=None,
#     109              trajectory_func=None):
# --> 111     self._modules = self._get_module_container(modules,
#     112                                                add_unbalanced_module,
#     113                                                loss_load_cost,
#     114                                                overgeneration_cost)
#     116     # TODO (ahalev) transform envs to wrappers, and remove microgrid from attr names)
#     117     self.microgrid_action_space = MicrogridSpace.from_module_spaces(
#     118         self._modules.get_attrs('action_space', 'module_type', as_pandas=False), 'act')
#
# File ~/Developer/MasterThesis/master-thesis-quantumkernelclassification/.venv/lib/python3.12/site-packages/pymgrid/microgrid/microgrid.py:173, in Microgrid._get_module_container(self, modules, add_unbalanced_module, loss_load_cost, overgeneration_cost)
#     170     raise TypeError("modules must be list-like of modules.")
#     172 if add_unbalanced_module:
# --> 173     modules.append(self._get_unbalanced_energy_module(loss_load_cost, overgeneration_cost))
#     175 return ModuleContainer(modules)
#
# AttributeError: 'dict' object has no attribute 'append'
